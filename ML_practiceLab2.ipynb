# %% [markdown]
# <a href="https://colab.research.google.com/github/95871abhinandankumar/95871abhinandankumar/blob/main/ML_practiceLab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

dataset = pd.read_csv("salary_data.csv")
print(dataset)
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
print("Total features :", len(dataset.columns) -1)
print("Total patterns :", dataset.shape[0])


minimum = dataset['Salary'].min()
maximum = dataset['Salary'].max()
print("Range of output :", (minimum, maximum))
# Out:
# Total features : 1
# Total patterns : 30
# Range of output : (37731, 122391)

# %%
x = .1
dataset1 = dataset.copy()
while x <= .9:
  y=1-x
  dataset1 = dataset.copy()
  x_part = dataset1.sample(frac = x)
  y_part = dataset1.drop(x_part.index)

  print("Showing the dataset ....", x, ':' , y)
  print("x part ...")
  print(x_part)
  print("y part ...")
  print(y_part)


  x += .1
# Out:
# Showing the dataset .... 0.1 : 0.9
# x part ...
#     YearsExperience  Salary
# 9               3.7   57189
# 23              8.2  113812
# 4               2.2   39891
# y part ...
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# ...

# %%
print("Row wise mean ....\n", dataset.mean(axis=1))
print("\n\n\nrow wise median....\n", dataset.median(axis=1))
print("\n\n\nrow wise mode....\n", dataset.mode(axis=1))
print("\n\n\nrow wise standard deviation....\n", dataset.std(axis=1))
# Out:
# Row wise mean ....
#  0     19672.05
# 1     23103.15
# 2     18866.25
# 3     21763.50
# 4     19946.60
# 5     28322.45
# 6     30076.50
# 7     27224.10
# 8     32224.10
# 9     28596.35
# 10    31610.95
# 11    27899.00
# 12    28480.50
# 13    28542.55
# 14    30557.75
# 15    33971.45
# 16    33017.05
# 17    41546.65
# 18    40684.45
# 19    46973.00
# 20    45872.40
# 21    49140.05
# 22    50654.95
# 23    56910.10
# 24    54719.85
# 25    52795.50
# 26    58489.25
# 27    56322.30
# 28    61200.65
# 29    60941.25
# dtype: float64
#
#
#
# row wise median....
#  0     19672.05
# 1     23103.15
# 2     18866.25
# 3     21763.50
# 4     19946.60
# 5     28322.45
# 6     30076.50
# 7     27224.10
# 8     32224.10
# 9     28596.35
# 10    31610.95
# 11    27899.00
# 12    28480.50
# 13    28542.55
# 14    30557.75
# 15    33971.45
# 16    33017.05
# 17    41546.65
# 18    40684.45
# 19    46973.00
# 20    45872.40
# 21    49140.05
# 22    50654.95
# 23    56910.10
# ...

# %%
print("column wise mean ....\n", dataset.mean(axis=0))
print("\n\n\ncolumn wise median....\n", dataset.median(axis=0))
print("\n\n\ncolumn wise mode....\n", dataset.mode(axis=0))
print("\n\n\ncolumn wise standard deviation....\n", dataset.std(axis=0))
# Out:
# column wise mean ....
#  YearsExperience        5.313333
# Salary             76003.000000
# dtype: float64
#
#
#
# column wise median....
#  YearsExperience        4.7
# Salary             65237.0
# dtype: float64
#
#
#
# column wise mode....
#      YearsExperience  Salary
# 0               3.2   37731
# 1               4.0   39343
# 2               NaN   39891
# 3               NaN   43525
# 4               NaN   46205
# 5               NaN   54445
# 6               NaN   55794
# 7               NaN   56642
# 8               NaN   56957
# 9               NaN   57081
# 10              NaN   57189
# 11              NaN   60150
# 12              NaN   61111
# 13              NaN   63218
# 14              NaN   64445
# 15              NaN   66029
# 16              NaN   67938
# 17              NaN   81363
# 18              NaN   83088
# 19              NaN   91738
# 20              NaN   93940
# 21              NaN   98273
# 22              NaN  101302
# 23              NaN  105582
# ...

# %%
print("Overall mean ....\n", dataset.mean())
print("\n\n\nOverall median....\n", dataset.median())
print("\n\n\nOverall mode....\n", dataset.mode())
print("\n\n\nOverall standard deviation....\n", dataset.std())
# Out:
# Overall mean ....
#  YearsExperience        5.313333
# Salary             76003.000000
# dtype: float64
#
#
#
# Overall median....
#  YearsExperience        4.7
# Salary             65237.0
# dtype: float64
#
#
#
# Overall mode....
#      YearsExperience  Salary
# 0               3.2   37731
# 1               4.0   39343
# 2               NaN   39891
# 3               NaN   43525
# 4               NaN   46205
# 5               NaN   54445
# 6               NaN   55794
# 7               NaN   56642
# 8               NaN   56957
# 9               NaN   57081
# 10              NaN   57189
# 11              NaN   60150
# 12              NaN   61111
# 13              NaN   63218
# 14              NaN   64445
# 15              NaN   66029
# 16              NaN   67938
# 17              NaN   81363
# 18              NaN   83088
# 19              NaN   91738
# 20              NaN   93940
# 21              NaN   98273
# 22              NaN  101302
# 23              NaN  105582
# ...

# %%
import numpy as np
from scipy.optimize import curve_fit

lst1 = dataset['YearsExperience']
lst2 = dataset['Salary']

def fit_func(x, a, b):
    return a*x + b

params = curve_fit(fit_func, lst1, lst2)

[a, b] = params[0]

pred_y = [0]*len(lst2)

k = 0
for i in lst1:
  pred_y[k] = fit_func(i, a, b);
  k += 1
#print(pred_y)

MSE = np.square(np.subtract(lst2, pred_y)).mean()*dataset.shape[0]
print(MSE)
# Out:
# 938128551.6684289
